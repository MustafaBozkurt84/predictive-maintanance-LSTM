# %% [markdown]
# <a href="https://colab.research.google.com/github/MustafaBozkurt84/predictive-maintanance-LSTM/blob/master/Lstm_Predictive_maintance_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# Setting seed for reproducibility
np.random.seed(1234)  
PYTHONHASHSEED = 0

from sklearn import preprocessing
from sklearn.metrics import confusion_matrix, recall_score, precision_score
from keras.models import Sequential,load_model
from keras.layers import Dense, Dropout, LSTM


##################################
# Data Ingestion
##################################

# read training data - It is the aircraft engine run-to-failure data.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_excel("/content/drive/MyDrive/Datasets/predictive maintance /AnalizDataPM.xlsx",engine='openpyxl')
df["Time"]= [str(i).replace("2020-02-02","2/2/2020").replace("2020-01-02","2/1/2020") for i in df["Time"]]
df['Time'] = pd.to_datetime(df['Time']) 
df['Time']=[str(i).split(":")[0] for i in df["Time"]]
df['Time'] = pd.to_datetime(df['Time'],format="%Y-%m-%d %H") #%Y-%m-%d %H:%M:%S
df=df.groupby("Time").mean()
df.reset_index(inplace=True)
df.to_csv("/content/drive/MyDrive/Datasets/predictive maintance /DataAnaliz.csv")
df.head()
# Out:
#                  Time      vibx      vibz  ...      zacc     crest     zfreq
# 0 2020-01-17 00:00:00  1.208404  0.968665  ...  0.260534  3.817392  0.070044
# 1 2020-01-17 01:00:00  1.173835  1.045636  ...  0.262390  3.857893  0.069983
# 2 2020-01-17 02:00:00  1.161203  0.959516  ...  0.259026  3.811876  0.069978
# 3 2020-01-17 03:00:00  1.191830  0.957197  ...  0.260562  3.833699  0.070006
# 4 2020-01-17 04:00:00  1.027394  0.860651  ...  0.231498  4.164031  0.060902
#
# [5 rows x 7 columns]

# %%
fail_time =df[df["Time"]=="2020-01-27 14:00:00"].index[0]

# %%
df["rul"]=[254-i for i in df.index]

# %%
train_df=df[df["Time"]<="2020-01-27 14:00:00"]
test_df = df[df["Time"]>"2020-01-27 14:00:00"]
test_df["rul"]=[i-254 for i in df[df["Time"]>"2020-01-27 14:00:00"].index]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
w0=36
w1=12
train_df["label1"]=np.where(train_df["rul"]< w0,1,0)
test_df["label1"]=np.where(test_df["rul"]< 0,1,0)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
train_df["label2"]=np.where(train_df["rul"]<w1,2,0)
test_df["label2"]=np.where(test_df["rul"]<0,1,0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-6b7d5a2702a2> in <module>()
# ----> 1 train_df["label2"]=np.where(train_df["rul"]<w1,2,0)
#       2 test_df["label2"]=np.where(test_df["rul"]<0,1,0)
#
# NameError: name 'w1' is not defined

# %%
# MinMax normalization (from 0 to 1)

cols_normalize = train_df.columns.difference(['Time','rul',"label2","label1"])
min_max_scaler = preprocessing.MinMaxScaler(feature_range=(0,1))
norm_train_df = pd.DataFrame(min_max_scaler.fit_transform(train_df[cols_normalize]), 
                             columns=cols_normalize, 
                             index=train_df.index)
join_df = train_df[train_df.columns.difference(cols_normalize)].join(norm_train_df)
train_df = join_df.reindex(columns = train_df.columns)

#Test


norm_test_df = pd.DataFrame(min_max_scaler.transform(test_df[cols_normalize]), 
                            columns=cols_normalize, 
                            index=test_df.index)
test_join_df = test_df[test_df.columns.difference(cols_normalize)].join(norm_test_df)
test_df = test_join_df.reindex(columns = test_df.columns)
test_df = test_df.reset_index(drop=True)

# %%
train_df
# Out:
#                    Time      vibx      vibz  ...  rul  label1  label2
# 0   2020-01-17 00:00:00  0.490650  0.288555  ...  254       0       0
# 1   2020-01-17 01:00:00  0.474892  0.315152  ...  253       0       0
# 2   2020-01-17 02:00:00  0.469133  0.285393  ...  252       0       0
# 3   2020-01-17 03:00:00  0.483095  0.284592  ...  251       0       0
# 4   2020-01-17 04:00:00  0.408137  0.251231  ...  250       0       0
# ..                  ...       ...       ...  ...  ...     ...     ...
# 250 2020-01-27 10:00:00  0.875471  0.270724  ...    4       1       2
# 251 2020-01-27 11:00:00  0.870527  0.274397  ...    3       1       2
# 252 2020-01-27 12:00:00  0.722010  0.194265  ...    2       1       2
# 253 2020-01-27 13:00:00  0.943146  0.276498  ...    1       1       2
# 254 2020-01-27 14:00:00  0.937059  0.271492  ...    0       1       2
#
# [255 rows x 10 columns]

# %%
test_df
# Out:
#                    Time      vibx      vibz  ...  rul  label1  label2
# 0   2020-01-27 15:00:00  0.920649  0.262588  ...    1       0       0
# 1   2020-01-27 16:00:00  0.916203  0.291659  ...    2       0       0
# 2   2020-01-27 17:00:00  0.929025  0.285568  ...    3       0       0
# 3   2020-01-27 18:00:00  0.915819  0.285907  ...    4       0       0
# 4   2020-01-27 19:00:00  0.918672  0.284766  ...    5       0       0
# ..                  ...       ...       ...  ...  ...     ...     ...
# 140 2020-02-02 14:00:00  0.015218  0.007606  ...  141       0       0
# 141 2020-02-02 15:00:00  0.032712  0.013931  ...  142       0       0
# 142 2020-02-02 16:00:00  0.972221  0.350657  ...  143       0       0
# 143 2020-02-02 17:00:00  0.784908  0.278872  ...  144       0       0
# 144 2020-02-02 18:00:00  0.727733  0.264839  ...  145       0       0
#
# [145 rows x 10 columns]

# %%
# pick  window size 
sequence_length = 10

# function to reshape features into (samples, time steps, features)

def gen_sequence(id_df, seq_length, seq_cols):
    """ Only sequences that meet the window-length are considered, no padding is used. This means for testing
    we need to drop those which are below the window-length. An alternative would be to pad sequences so that
    we can use shorter ones """
    # for one id I put all the rows in a single matrix
    data_matrix = id_df[seq_cols].values
    num_elements = data_matrix.shape[0]
    # Iterate over two lists in parallel.
    # For example id1 have 192 rows and sequence_length is equal to 50
    # so zip iterate over two following list of numbers (0,112),(50,192)
    # 0 50 -> from row 0 to row 50
    # 1 51 -> from row 1 to row 51
    # 2 52 -> from row 2 to row 52
    # ...
    # 111 191 -> from row 111 to 191
    for start, stop in zip(range(0, num_elements-seq_length), range(seq_length, num_elements)):
        yield data_matrix[start:stop, :]
        
# pick the feature columns 
sequence_cols=train_df.columns[1:7]

# generator for the sequences
#seq_gen=(list(gen_sequence(train_df[train_df.index==id], sequence_length, sequence_cols))  for id in train_df.index)
seq_gen = list(list(gen_sequence(train_df, sequence_length, sequence_cols)))
           

# generate sequences and convert to numpy array
seq_array = np.concatenate(list(seq_gen)).astype(np.float32)
    
seq_array=np.reshape(seq_array, (len(seq_gen),sequence_length,len(sequence_cols)))
print(seq_array.shape)
# Out:
# (245, 10, 6)

# %%
# function to generate labels
def gen_labels(id_df, seq_length, label):
    # For one id I put all the labels in a single matrix.
    # For example:
    # [[1]
    # [4]
    # [1]
    # [5]
    # [9]
    # ...
    # [200]] 
    data_matrix = id_df[label].values
    num_elements = data_matrix.shape[0]
    # I have to remove the first seq_length labels
    # because for one id the first sequence of seq_length size have as target
    # the last label (the previus ones are discarded).
    # All the next id's sequences will have associated step by step one label as target. 
    return data_matrix[seq_length:num_elements, :]

# generate labels
label_gen = [gen_labels(train_df, sequence_length, ['label1'])]
label_array = np.concatenate(label_gen).astype(np.float32)
print(label_array.shape)
# Out:
# (245, 1)

# %%
model_path = 'classification_model.h5'

# %%
# Next, we build a deep network. 
# The first layer is an LSTM layer with 100 units followed by another LSTM layer with 50 units. 
# Dropout is also applied after each LSTM layer to control overfitting. 
# Final layer is a Dense output layer with single unit and sigmoid activation since this is a binary classification problem.
# build the network

nb_features = seq_array.shape[2]
nb_out = label_array.shape[1]

model = Sequential()

model.add(LSTM(
         input_shape=(sequence_length, nb_features),
         units=100,
         return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(
          units=50,
          return_sequences=False))
model.add(Dropout(0.2))

model.add(Dense(units=nb_out, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

print(model.summary())

# fit the network
history = model.fit(seq_array, label_array, epochs=200, batch_size=3, validation_split=False, verbose=2,
          callbacks = [keras.callbacks.EarlyStopping(monitor='loss', min_delta=0, patience=50, verbose=0, mode='min'),
                       keras.callbacks.ModelCheckpoint(model_path,monitor='loss', save_best_only=True, mode='min', verbose=1)]
          )

# list all data in history
print(history.history.keys())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 10, 100)           42800
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 10, 100)           0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 50)                30200
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 73,051
# Trainable params: 73,051
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 82/82 - 4s - loss: 0.3885 - accuracy: 0.8735
#
# Epoch 00001: loss improved from inf to 0.38845, saving model to classification_model.h5
# Epoch 2/200
# 82/82 - 1s - loss: 0.3029 - accuracy: 0.9020
#
# Epoch 00002: loss improved from 0.38845 to 0.30291, saving model to classification_model.h5
# Epoch 3/200
# 82/82 - 1s - loss: 0.3017 - accuracy: 0.9020
#
# Epoch 00003: loss improved from 0.30291 to 0.30169, saving model to classification_model.h5
# Epoch 4/200
# 82/82 - 1s - loss: 0.2854 - accuracy: 0.8980
#
# Epoch 00004: loss improved from 0.30169 to 0.28538, saving model to classification_model.h5
# Epoch 5/200
# 82/82 - 1s - loss: 0.2901 - accuracy: 0.9020
#
# Epoch 00005: loss did not improve from 0.28538
# Epoch 6/200
# 82/82 - 1s - loss: 0.2616 - accuracy: 0.9020
#
# Epoch 00006: loss improved from 0.28538 to 0.26155, saving model to classification_model.h5
# Epoch 7/200
# 82/82 - 1s - loss: 0.2192 - accuracy: 0.9061
#
# Epoch 00007: loss improved from 0.26155 to 0.21919, saving model to classification_model.h5
# Epoch 8/200
# 82/82 - 1s - loss: 0.1999 - accuracy: 0.9347
#
# Epoch 00008: loss improved from 0.21919 to 0.19985, saving model to classification_model.h5
# Epoch 9/200
# 82/82 - 1s - loss: 0.1771 - accuracy: 0.9388
#
# Epoch 00009: loss improved from 0.19985 to 0.17706, saving model to classification_model.h5
# Epoch 10/200
# 82/82 - 1s - loss: 0.1939 - accuracy: 0.9306
#
# Epoch 00010: loss did not improve from 0.17706
# Epoch 11/200
# 82/82 - 1s - loss: 0.1652 - accuracy: 0.9429
#
# Epoch 00011: loss improved from 0.17706 to 0.16517, saving model to classification_model.h5
# Epoch 12/200
# 82/82 - 1s - loss: 0.1851 - accuracy: 0.9265
#
# Epoch 00012: loss did not improve from 0.16517
# Epoch 13/200
# 82/82 - 1s - loss: 0.1636 - accuracy: 0.9306
#
# Epoch 00013: loss improved from 0.16517 to 0.16364, saving model to classification_model.h5
# Epoch 14/200
# 82/82 - 1s - loss: 0.1534 - accuracy: 0.9347
#
# Epoch 00014: loss improved from 0.16364 to 0.15338, saving model to classification_model.h5
# Epoch 15/200
# 82/82 - 1s - loss: 0.1522 - accuracy: 0.9347
#
# Epoch 00015: loss improved from 0.15338 to 0.15219, saving model to classification_model.h5
# Epoch 16/200
# 82/82 - 1s - loss: 0.1409 - accuracy: 0.9388
#
# Epoch 00016: loss improved from 0.15219 to 0.14091, saving model to classification_model.h5
# Epoch 17/200
# 82/82 - 1s - loss: 0.1374 - accuracy: 0.9388
#
# Epoch 00017: loss improved from 0.14091 to 0.13738, saving model to classification_model.h5
# Epoch 18/200
# 82/82 - 1s - loss: 0.1460 - accuracy: 0.9429
#
# Epoch 00018: loss did not improve from 0.13738
# Epoch 19/200
# 82/82 - 1s - loss: 0.1458 - accuracy: 0.9429
#
# Epoch 00019: loss did not improve from 0.13738
# Epoch 20/200
# 82/82 - 1s - loss: 0.1406 - accuracy: 0.9429
#
# Epoch 00020: loss did not improve from 0.13738
# Epoch 21/200
# 82/82 - 1s - loss: 0.1258 - accuracy: 0.9510
#
# Epoch 00021: loss improved from 0.13738 to 0.12576, saving model to classification_model.h5
# Epoch 22/200
# 82/82 - 1s - loss: 0.1402 - accuracy: 0.9429
#
# Epoch 00022: loss did not improve from 0.12576
# Epoch 23/200
# 82/82 - 1s - loss: 0.1256 - accuracy: 0.9469
#
# Epoch 00023: loss improved from 0.12576 to 0.12561, saving model to classification_model.h5
# Epoch 24/200
# 82/82 - 1s - loss: 0.1159 - accuracy: 0.9510
#
# Epoch 00024: loss improved from 0.12561 to 0.11594, saving model to classification_model.h5
# Epoch 25/200
# 82/82 - 1s - loss: 0.1098 - accuracy: 0.9469
#
# Epoch 00025: loss improved from 0.11594 to 0.10984, saving model to classification_model.h5
# Epoch 26/200
# 82/82 - 1s - loss: 0.1287 - accuracy: 0.9469
#
# Epoch 00026: loss did not improve from 0.10984
# Epoch 27/200
# 82/82 - 1s - loss: 0.1128 - accuracy: 0.9633
#
# Epoch 00027: loss did not improve from 0.10984
# Epoch 28/200
# 82/82 - 1s - loss: 0.0977 - accuracy: 0.9633
#
# Epoch 00028: loss improved from 0.10984 to 0.09770, saving model to classification_model.h5
# Epoch 29/200
# 82/82 - 1s - loss: 0.1183 - accuracy: 0.9551
#
# Epoch 00029: loss did not improve from 0.09770
# Epoch 30/200
# 82/82 - 1s - loss: 0.1107 - accuracy: 0.9592
#
# Epoch 00030: loss did not improve from 0.09770
# Epoch 31/200
# 82/82 - 1s - loss: 0.1097 - accuracy: 0.9633
#
# Epoch 00031: loss did not improve from 0.09770
# Epoch 32/200
# 82/82 - 1s - loss: 0.1120 - accuracy: 0.9592
#
# Epoch 00032: loss did not improve from 0.09770
# Epoch 33/200
# 82/82 - 1s - loss: 0.0869 - accuracy: 0.9592
#
# Epoch 00033: loss improved from 0.09770 to 0.08693, saving model to classification_model.h5
# Epoch 34/200
# 82/82 - 1s - loss: 0.1277 - accuracy: 0.9592
#
# Epoch 00034: loss did not improve from 0.08693
# Epoch 35/200
# 82/82 - 1s - loss: 0.0894 - accuracy: 0.9796
#
# Epoch 00035: loss did not improve from 0.08693
# Epoch 36/200
# 82/82 - 1s - loss: 0.0941 - accuracy: 0.9673
#
# Epoch 00036: loss did not improve from 0.08693
# Epoch 37/200
# 82/82 - 1s - loss: 0.1130 - accuracy: 0.9510
#
# Epoch 00037: loss did not improve from 0.08693
# Epoch 38/200
# 82/82 - 1s - loss: 0.0779 - accuracy: 0.9673
#
# Epoch 00038: loss improved from 0.08693 to 0.07790, saving model to classification_model.h5
# Epoch 39/200
# 82/82 - 1s - loss: 0.1050 - accuracy: 0.9633
#
# Epoch 00039: loss did not improve from 0.07790
# Epoch 40/200
# 82/82 - 1s - loss: 0.1111 - accuracy: 0.9673
#
# Epoch 00040: loss did not improve from 0.07790
# Epoch 41/200
# 82/82 - 1s - loss: 0.0913 - accuracy: 0.9510
#
# Epoch 00041: loss did not improve from 0.07790
# Epoch 42/200
# 82/82 - 1s - loss: 0.0816 - accuracy: 0.9714
#
# Epoch 00042: loss did not improve from 0.07790
# Epoch 43/200
# 82/82 - 1s - loss: 0.0441 - accuracy: 0.9918
#
# Epoch 00043: loss improved from 0.07790 to 0.04413, saving model to classification_model.h5
# Epoch 44/200
# 82/82 - 1s - loss: 0.0687 - accuracy: 0.9837
#
# Epoch 00044: loss did not improve from 0.04413
# Epoch 45/200
# 82/82 - 1s - loss: 0.0647 - accuracy: 0.9673
#
# Epoch 00045: loss did not improve from 0.04413
# Epoch 46/200
# 82/82 - 1s - loss: 0.0611 - accuracy: 0.9673
#
# Epoch 00046: loss did not improve from 0.04413
# Epoch 47/200
# 82/82 - 1s - loss: 0.0555 - accuracy: 0.9837
#
# Epoch 00047: loss did not improve from 0.04413
# Epoch 48/200
# 82/82 - 1s - loss: 0.0263 - accuracy: 0.9918
#
# Epoch 00048: loss improved from 0.04413 to 0.02628, saving model to classification_model.h5
# Epoch 49/200
# 82/82 - 1s - loss: 0.0476 - accuracy: 0.9755
#
# Epoch 00049: loss did not improve from 0.02628
# Epoch 50/200
# 82/82 - 1s - loss: 0.0969 - accuracy: 0.9755
#
# Epoch 00050: loss did not improve from 0.02628
# Epoch 51/200
# 82/82 - 1s - loss: 0.0503 - accuracy: 0.9878
#
# Epoch 00051: loss did not improve from 0.02628
# Epoch 52/200
# 82/82 - 1s - loss: 0.0506 - accuracy: 0.9837
#
# Epoch 00052: loss did not improve from 0.02628
# Epoch 53/200
# 82/82 - 1s - loss: 0.0430 - accuracy: 0.9878
#
# Epoch 00053: loss did not improve from 0.02628
# Epoch 54/200
# 82/82 - 1s - loss: 0.0559 - accuracy: 0.9755
#
# Epoch 00054: loss did not improve from 0.02628
# Epoch 55/200
# 82/82 - 1s - loss: 0.0158 - accuracy: 1.0000
#
# Epoch 00055: loss improved from 0.02628 to 0.01577, saving model to classification_model.h5
# Epoch 56/200
# 82/82 - 1s - loss: 0.0471 - accuracy: 0.9796
#
# Epoch 00056: loss did not improve from 0.01577
# Epoch 57/200
# 82/82 - 1s - loss: 0.0384 - accuracy: 0.9878
#
# Epoch 00057: loss did not improve from 0.01577
# Epoch 58/200
# 82/82 - 1s - loss: 0.0542 - accuracy: 0.9837
#
# Epoch 00058: loss did not improve from 0.01577
# Epoch 59/200
# 82/82 - 1s - loss: 0.0376 - accuracy: 0.9878
#
# Epoch 00059: loss did not improve from 0.01577
# Epoch 60/200
# 82/82 - 1s - loss: 0.0204 - accuracy: 0.9959
#
# Epoch 00060: loss did not improve from 0.01577
# Epoch 61/200
# 82/82 - 1s - loss: 0.0111 - accuracy: 1.0000
#
# Epoch 00061: loss improved from 0.01577 to 0.01113, saving model to classification_model.h5
# Epoch 62/200
# 82/82 - 1s - loss: 0.0085 - accuracy: 1.0000
#
# Epoch 00062: loss improved from 0.01113 to 0.00854, saving model to classification_model.h5
# Epoch 63/200
# 82/82 - 1s - loss: 0.0186 - accuracy: 0.9918
#
# Epoch 00063: loss did not improve from 0.00854
# Epoch 64/200
# 82/82 - 1s - loss: 0.0567 - accuracy: 0.9878
#
# Epoch 00064: loss did not improve from 0.00854
# Epoch 65/200
# 82/82 - 1s - loss: 0.0195 - accuracy: 0.9959
#
# Epoch 00065: loss did not improve from 0.00854
# Epoch 66/200
# 82/82 - 1s - loss: 0.0065 - accuracy: 1.0000
#
# Epoch 00066: loss improved from 0.00854 to 0.00648, saving model to classification_model.h5
# Epoch 67/200
# 82/82 - 1s - loss: 0.0049 - accuracy: 1.0000
#
# Epoch 00067: loss improved from 0.00648 to 0.00487, saving model to classification_model.h5
# Epoch 68/200
# 82/82 - 1s - loss: 0.0036 - accuracy: 1.0000
#
# Epoch 00068: loss improved from 0.00487 to 0.00362, saving model to classification_model.h5
# Epoch 69/200
# 82/82 - 1s - loss: 0.0033 - accuracy: 1.0000
#
# Epoch 00069: loss improved from 0.00362 to 0.00327, saving model to classification_model.h5
# Epoch 70/200
# 82/82 - 1s - loss: 0.0024 - accuracy: 1.0000
#
# Epoch 00070: loss improved from 0.00327 to 0.00239, saving model to classification_model.h5
# Epoch 71/200
# 82/82 - 1s - loss: 0.0023 - accuracy: 1.0000
#
# Epoch 00071: loss improved from 0.00239 to 0.00232, saving model to classification_model.h5
# Epoch 72/200
# 82/82 - 1s - loss: 0.0016 - accuracy: 1.0000
#
# Epoch 00072: loss improved from 0.00232 to 0.00165, saving model to classification_model.h5
# Epoch 73/200
# 82/82 - 1s - loss: 0.0013 - accuracy: 1.0000
#
# Epoch 00073: loss improved from 0.00165 to 0.00132, saving model to classification_model.h5
# Epoch 74/200
# 82/82 - 1s - loss: 0.0028 - accuracy: 1.0000
#
# Epoch 00074: loss did not improve from 0.00132
# Epoch 75/200
# 82/82 - 1s - loss: 0.0053 - accuracy: 1.0000
#
# Epoch 00075: loss did not improve from 0.00132
# Epoch 76/200
# 82/82 - 1s - loss: 0.0031 - accuracy: 1.0000
#
# Epoch 00076: loss did not improve from 0.00132
# Epoch 77/200
# 82/82 - 1s - loss: 0.0018 - accuracy: 1.0000
#
# Epoch 00077: loss did not improve from 0.00132
# Epoch 78/200
# 82/82 - 1s - loss: 8.3227e-04 - accuracy: 1.0000
#
# Epoch 00078: loss improved from 0.00132 to 0.00083, saving model to classification_model.h5
# Epoch 79/200
# 82/82 - 1s - loss: 0.0014 - accuracy: 1.0000
#
# Epoch 00079: loss did not improve from 0.00083
# Epoch 80/200
# 82/82 - 1s - loss: 0.0717 - accuracy: 0.9878
#
# Epoch 00080: loss did not improve from 0.00083
# Epoch 81/200
# 82/82 - 1s - loss: 0.0693 - accuracy: 0.9714
#
# Epoch 00081: loss did not improve from 0.00083
# Epoch 82/200
# 82/82 - 1s - loss: 0.1259 - accuracy: 0.9551
#
# Epoch 00082: loss did not improve from 0.00083
# Epoch 83/200
# 82/82 - 1s - loss: 0.0294 - accuracy: 0.9959
#
# Epoch 00083: loss did not improve from 0.00083
# Epoch 84/200
# 82/82 - 1s - loss: 0.0109 - accuracy: 1.0000
#
# Epoch 00084: loss did not improve from 0.00083
# Epoch 85/200
# 82/82 - 1s - loss: 0.0105 - accuracy: 0.9959
#
# Epoch 00085: loss did not improve from 0.00083
# Epoch 86/200
# 82/82 - 1s - loss: 0.0055 - accuracy: 1.0000
#
# Epoch 00086: loss did not improve from 0.00083
# Epoch 87/200
# 82/82 - 1s - loss: 0.0026 - accuracy: 1.0000
#
# Epoch 00087: loss did not improve from 0.00083
# Epoch 88/200
# 82/82 - 1s - loss: 0.0025 - accuracy: 1.0000
#
# Epoch 00088: loss did not improve from 0.00083
# Epoch 89/200
# 82/82 - 1s - loss: 0.0019 - accuracy: 1.0000
#
# Epoch 00089: loss did not improve from 0.00083
# Epoch 90/200
# 82/82 - 1s - loss: 0.0015 - accuracy: 1.0000
#
# Epoch 00090: loss did not improve from 0.00083
# Epoch 91/200
# 82/82 - 1s - loss: 0.0013 - accuracy: 1.0000
#
# Epoch 00091: loss did not improve from 0.00083
# Epoch 92/200
# 82/82 - 1s - loss: 0.0018 - accuracy: 1.0000
#
# Epoch 00092: loss did not improve from 0.00083
# Epoch 93/200
# 82/82 - 1s - loss: 0.0015 - accuracy: 1.0000
#
# Epoch 00093: loss did not improve from 0.00083
# Epoch 94/200
# 82/82 - 1s - loss: 0.0012 - accuracy: 1.0000
#
# Epoch 00094: loss did not improve from 0.00083
# Epoch 95/200
# 82/82 - 1s - loss: 0.0010 - accuracy: 1.0000
#
# Epoch 00095: loss did not improve from 0.00083
# Epoch 96/200
# 82/82 - 1s - loss: 0.0014 - accuracy: 1.0000
#
# Epoch 00096: loss did not improve from 0.00083
# Epoch 97/200
# 82/82 - 1s - loss: 0.0012 - accuracy: 1.0000
#
# Epoch 00097: loss did not improve from 0.00083
# Epoch 98/200
# 82/82 - 1s - loss: 5.0616e-04 - accuracy: 1.0000
#
# Epoch 00098: loss improved from 0.00083 to 0.00051, saving model to classification_model.h5
# Epoch 99/200
# 82/82 - 1s - loss: 7.9271e-04 - accuracy: 1.0000
#
# Epoch 00099: loss did not improve from 0.00051
# Epoch 100/200
# 82/82 - 1s - loss: 4.7604e-04 - accuracy: 1.0000
#
# Epoch 00100: loss improved from 0.00051 to 0.00048, saving model to classification_model.h5
# Epoch 101/200
# 82/82 - 1s - loss: 5.2932e-04 - accuracy: 1.0000
#
# Epoch 00101: loss did not improve from 0.00048
# Epoch 102/200
# 82/82 - 1s - loss: 4.0921e-04 - accuracy: 1.0000
#
# Epoch 00102: loss improved from 0.00048 to 0.00041, saving model to classification_model.h5
# Epoch 103/200
# 82/82 - 1s - loss: 2.9975e-04 - accuracy: 1.0000
#
# Epoch 00103: loss improved from 0.00041 to 0.00030, saving model to classification_model.h5
# Epoch 104/200
# 82/82 - 1s - loss: 3.1759e-04 - accuracy: 1.0000
#
# Epoch 00104: loss did not improve from 0.00030
# Epoch 105/200
# 82/82 - 1s - loss: 9.8334e-04 - accuracy: 1.0000
#
# Epoch 00105: loss did not improve from 0.00030
# Epoch 106/200
# 82/82 - 1s - loss: 5.4819e-04 - accuracy: 1.0000
#
# Epoch 00106: loss did not improve from 0.00030
# Epoch 107/200
# 82/82 - 1s - loss: 6.0794e-04 - accuracy: 1.0000
#
# Epoch 00107: loss did not improve from 0.00030
# Epoch 108/200
# 82/82 - 1s - loss: 0.0481 - accuracy: 0.9837
#
# Epoch 00108: loss did not improve from 0.00030
# Epoch 109/200
# 82/82 - 1s - loss: 0.1086 - accuracy: 0.9755
#
# Epoch 00109: loss did not improve from 0.00030
# Epoch 110/200
# 82/82 - 1s - loss: 0.0655 - accuracy: 0.9714
#
# Epoch 00110: loss did not improve from 0.00030
# Epoch 111/200
# 82/82 - 1s - loss: 0.1051 - accuracy: 0.9551
#
# Epoch 00111: loss did not improve from 0.00030
# Epoch 112/200
# 82/82 - 1s - loss: 0.0435 - accuracy: 0.9755
#
# Epoch 00112: loss did not improve from 0.00030
# Epoch 113/200
# 82/82 - 1s - loss: 0.0270 - accuracy: 0.9918
#
# Epoch 00113: loss did not improve from 0.00030
# Epoch 114/200
# 82/82 - 1s - loss: 0.0274 - accuracy: 0.9918
#
# Epoch 00114: loss did not improve from 0.00030
# Epoch 115/200
# 82/82 - 1s - loss: 0.0268 - accuracy: 0.9837
#
# Epoch 00115: loss did not improve from 0.00030
# Epoch 116/200
# 82/82 - 1s - loss: 0.0122 - accuracy: 0.9959
#
# Epoch 00116: loss did not improve from 0.00030
# Epoch 117/200
# 82/82 - 1s - loss: 0.0093 - accuracy: 1.0000
#
# Epoch 00117: loss did not improve from 0.00030
# Epoch 118/200
# 82/82 - 1s - loss: 0.0110 - accuracy: 0.9959
#
# Epoch 00118: loss did not improve from 0.00030
# Epoch 119/200
# 82/82 - 1s - loss: 0.0062 - accuracy: 0.9959
#
# Epoch 00119: loss did not improve from 0.00030
# Epoch 120/200
# 82/82 - 1s - loss: 0.0027 - accuracy: 1.0000
#
# Epoch 00120: loss did not improve from 0.00030
# Epoch 121/200
# 82/82 - 1s - loss: 0.0018 - accuracy: 1.0000
#
# Epoch 00121: loss did not improve from 0.00030
# Epoch 122/200
# 82/82 - 1s - loss: 0.0017 - accuracy: 1.0000
#
# Epoch 00122: loss did not improve from 0.00030
# Epoch 123/200
# 82/82 - 1s - loss: 0.0012 - accuracy: 1.0000
#
# Epoch 00123: loss did not improve from 0.00030
# Epoch 124/200
# 82/82 - 1s - loss: 0.0046 - accuracy: 1.0000
#
# Epoch 00124: loss did not improve from 0.00030
# Epoch 125/200
# 82/82 - 1s - loss: 0.0044 - accuracy: 1.0000
#
# Epoch 00125: loss did not improve from 0.00030
# Epoch 126/200
# 82/82 - 1s - loss: 0.0011 - accuracy: 1.0000
#
# Epoch 00126: loss did not improve from 0.00030
# Epoch 127/200
# 82/82 - 1s - loss: 6.8176e-04 - accuracy: 1.0000
#
# Epoch 00127: loss did not improve from 0.00030
# Epoch 128/200
# 82/82 - 1s - loss: 6.9858e-04 - accuracy: 1.0000
#
# Epoch 00128: loss did not improve from 0.00030
# Epoch 129/200
# 82/82 - 1s - loss: 5.3714e-04 - accuracy: 1.0000
#
# Epoch 00129: loss did not improve from 0.00030
# Epoch 130/200
# 82/82 - 1s - loss: 3.1567e-04 - accuracy: 1.0000
#
# Epoch 00130: loss did not improve from 0.00030
# Epoch 131/200
# 82/82 - 1s - loss: 3.9342e-04 - accuracy: 1.0000
#
# Epoch 00131: loss did not improve from 0.00030
# Epoch 132/200
# 82/82 - 1s - loss: 3.9119e-04 - accuracy: 1.0000
#
# Epoch 00132: loss did not improve from 0.00030
# Epoch 133/200
# 82/82 - 1s - loss: 2.7545e-04 - accuracy: 1.0000
#
# Epoch 00133: loss improved from 0.00030 to 0.00028, saving model to classification_model.h5
# Epoch 134/200
# 82/82 - 1s - loss: 2.1108e-04 - accuracy: 1.0000
#
# Epoch 00134: loss improved from 0.00028 to 0.00021, saving model to classification_model.h5
# Epoch 135/200
# 82/82 - 1s - loss: 0.0010 - accuracy: 1.0000
#
# Epoch 00135: loss did not improve from 0.00021
# Epoch 136/200
# 82/82 - 1s - loss: 2.6317e-04 - accuracy: 1.0000
#
# Epoch 00136: loss did not improve from 0.00021
# Epoch 137/200
# 82/82 - 1s - loss: 2.1235e-04 - accuracy: 1.0000
#
# Epoch 00137: loss did not improve from 0.00021
# Epoch 138/200
# 82/82 - 1s - loss: 2.7526e-04 - accuracy: 1.0000
#
# Epoch 00138: loss did not improve from 0.00021
# Epoch 139/200
# 82/82 - 1s - loss: 1.9051e-04 - accuracy: 1.0000
#
# Epoch 00139: loss improved from 0.00021 to 0.00019, saving model to classification_model.h5
# Epoch 140/200
# 82/82 - 1s - loss: 1.9084e-04 - accuracy: 1.0000
#
# Epoch 00140: loss did not improve from 0.00019
# Epoch 141/200
# 82/82 - 1s - loss: 1.9180e-04 - accuracy: 1.0000
#
# Epoch 00141: loss did not improve from 0.00019
# Epoch 142/200
# 82/82 - 1s - loss: 3.3043e-04 - accuracy: 1.0000
#
# Epoch 00142: loss did not improve from 0.00019
# Epoch 143/200
# 82/82 - 1s - loss: 1.2934e-04 - accuracy: 1.0000
#
# Epoch 00143: loss improved from 0.00019 to 0.00013, saving model to classification_model.h5
# Epoch 144/200
# 82/82 - 1s - loss: 2.6777e-04 - accuracy: 1.0000
#
# Epoch 00144: loss did not improve from 0.00013
# Epoch 145/200
# 82/82 - 1s - loss: 2.4759e-04 - accuracy: 1.0000
#
# Epoch 00145: loss did not improve from 0.00013
# Epoch 146/200
# 82/82 - 1s - loss: 1.4269e-04 - accuracy: 1.0000
#
# Epoch 00146: loss did not improve from 0.00013
# Epoch 147/200
# 82/82 - 1s - loss: 1.5275e-04 - accuracy: 1.0000
#
# Epoch 00147: loss did not improve from 0.00013
# Epoch 148/200
# 82/82 - 1s - loss: 1.4515e-04 - accuracy: 1.0000
#
# Epoch 00148: loss did not improve from 0.00013
# Epoch 149/200
# 82/82 - 1s - loss: 9.4905e-05 - accuracy: 1.0000
#
# Epoch 00149: loss improved from 0.00013 to 0.00009, saving model to classification_model.h5
# Epoch 150/200
# 82/82 - 1s - loss: 1.0374e-04 - accuracy: 1.0000
#
# Epoch 00150: loss did not improve from 0.00009
# Epoch 151/200
# 82/82 - 1s - loss: 1.1902e-04 - accuracy: 1.0000
#
# Epoch 00151: loss did not improve from 0.00009
# Epoch 152/200
# 82/82 - 1s - loss: 1.1023e-04 - accuracy: 1.0000
#
# Epoch 00152: loss did not improve from 0.00009
# Epoch 153/200
# 82/82 - 1s - loss: 7.8096e-05 - accuracy: 1.0000
#
# Epoch 00153: loss improved from 0.00009 to 0.00008, saving model to classification_model.h5
# Epoch 154/200
# 82/82 - 1s - loss: 1.1083e-04 - accuracy: 1.0000
#
# Epoch 00154: loss did not improve from 0.00008
# Epoch 155/200
# 82/82 - 1s - loss: 6.6170e-05 - accuracy: 1.0000
#
# Epoch 00155: loss improved from 0.00008 to 0.00007, saving model to classification_model.h5
# Epoch 156/200
# 82/82 - 1s - loss: 1.2278e-04 - accuracy: 1.0000
#
# Epoch 00156: loss did not improve from 0.00007
# Epoch 157/200
# 82/82 - 1s - loss: 7.7470e-05 - accuracy: 1.0000
#
# Epoch 00157: loss did not improve from 0.00007
# Epoch 158/200
# 82/82 - 1s - loss: 8.5933e-05 - accuracy: 1.0000
#
# Epoch 00158: loss did not improve from 0.00007
# Epoch 159/200
# 82/82 - 1s - loss: 1.3413e-04 - accuracy: 1.0000
#
# Epoch 00159: loss did not improve from 0.00007
# Epoch 160/200
# 82/82 - 1s - loss: 9.3853e-05 - accuracy: 1.0000
#
# Epoch 00160: loss did not improve from 0.00007
# Epoch 161/200
# 82/82 - 1s - loss: 9.0384e-05 - accuracy: 1.0000
#
# Epoch 00161: loss did not improve from 0.00007
# Epoch 162/200
# 82/82 - 1s - loss: 8.5660e-05 - accuracy: 1.0000
#
# Epoch 00162: loss did not improve from 0.00007
# Epoch 163/200
# 82/82 - 1s - loss: 9.0166e-05 - accuracy: 1.0000
#
# Epoch 00163: loss did not improve from 0.00007
# Epoch 164/200
# 82/82 - 1s - loss: 1.0707e-04 - accuracy: 1.0000
#
# Epoch 00164: loss did not improve from 0.00007
# Epoch 165/200
# 82/82 - 1s - loss: 6.2369e-05 - accuracy: 1.0000
#
# Epoch 00165: loss improved from 0.00007 to 0.00006, saving model to classification_model.h5
# Epoch 166/200
# 82/82 - 1s - loss: 8.5384e-05 - accuracy: 1.0000
#
# Epoch 00166: loss did not improve from 0.00006
# Epoch 167/200
# 82/82 - 1s - loss: 1.0167e-04 - accuracy: 1.0000
#
# Epoch 00167: loss did not improve from 0.00006
# Epoch 168/200
# 82/82 - 1s - loss: 0.0651 - accuracy: 0.9755
#
# Epoch 00168: loss did not improve from 0.00006
# Epoch 169/200
# 82/82 - 1s - loss: 0.0472 - accuracy: 0.9878
#
# Epoch 00169: loss did not improve from 0.00006
# Epoch 170/200
# 82/82 - 1s - loss: 0.0073 - accuracy: 1.0000
#
# Epoch 00170: loss did not improve from 0.00006
# Epoch 171/200
# 82/82 - 1s - loss: 0.0050 - accuracy: 1.0000
#
# Epoch 00171: loss did not improve from 0.00006
# Epoch 172/200
# 82/82 - 1s - loss: 0.0021 - accuracy: 1.0000
#
# Epoch 00172: loss did not improve from 0.00006
# Epoch 173/200
# 82/82 - 1s - loss: 7.2647e-04 - accuracy: 1.0000
#
# Epoch 00173: loss did not improve from 0.00006
# Epoch 174/200
# 82/82 - 1s - loss: 6.5865e-04 - accuracy: 1.0000
#
# Epoch 00174: loss did not improve from 0.00006
# Epoch 175/200
# 82/82 - 1s - loss: 0.0016 - accuracy: 1.0000
#
# Epoch 00175: loss did not improve from 0.00006
# Epoch 176/200
# 82/82 - 1s - loss: 8.3867e-04 - accuracy: 1.0000
#
# Epoch 00176: loss did not improve from 0.00006
# Epoch 177/200
# 82/82 - 1s - loss: 3.1261e-04 - accuracy: 1.0000
#
# Epoch 00177: loss did not improve from 0.00006
# Epoch 178/200
# 82/82 - 1s - loss: 3.6514e-04 - accuracy: 1.0000
#
# Epoch 00178: loss did not improve from 0.00006
# Epoch 179/200
# 82/82 - 1s - loss: 3.9791e-04 - accuracy: 1.0000
#
# Epoch 00179: loss did not improve from 0.00006
# Epoch 180/200
# 82/82 - 1s - loss: 2.1289e-04 - accuracy: 1.0000
#
# Epoch 00180: loss did not improve from 0.00006
# Epoch 181/200
# 82/82 - 1s - loss: 3.5785e-04 - accuracy: 1.0000
#
# Epoch 00181: loss did not improve from 0.00006
# Epoch 182/200
# 82/82 - 1s - loss: 3.2898e-04 - accuracy: 1.0000
#
# Epoch 00182: loss did not improve from 0.00006
# Epoch 183/200
# 82/82 - 1s - loss: 2.8825e-04 - accuracy: 1.0000
#
# Epoch 00183: loss did not improve from 0.00006
# Epoch 184/200
# 82/82 - 1s - loss: 2.8098e-04 - accuracy: 1.0000
#
# Epoch 00184: loss did not improve from 0.00006
# Epoch 185/200
# 82/82 - 1s - loss: 0.0012 - accuracy: 1.0000
#
# Epoch 00185: loss did not improve from 0.00006
# Epoch 186/200
# 82/82 - 1s - loss: 2.2628e-04 - accuracy: 1.0000
#
# Epoch 00186: loss did not improve from 0.00006
# Epoch 187/200
# 82/82 - 1s - loss: 9.6835e-05 - accuracy: 1.0000
#
# Epoch 00187: loss did not improve from 0.00006
# Epoch 188/200
# 82/82 - 1s - loss: 1.2789e-04 - accuracy: 1.0000
#
# Epoch 00188: loss did not improve from 0.00006
# Epoch 189/200
# 82/82 - 1s - loss: 1.7522e-04 - accuracy: 1.0000
#
# Epoch 00189: loss did not improve from 0.00006
# Epoch 190/200
# 82/82 - 1s - loss: 1.2978e-04 - accuracy: 1.0000
#
# Epoch 00190: loss did not improve from 0.00006
# Epoch 191/200
# 82/82 - 1s - loss: 2.1073e-04 - accuracy: 1.0000
#
# Epoch 00191: loss did not improve from 0.00006
# Epoch 192/200
# 82/82 - 1s - loss: 8.5042e-05 - accuracy: 1.0000
#
# Epoch 00192: loss did not improve from 0.00006
# Epoch 193/200
# 82/82 - 1s - loss: 1.6171e-04 - accuracy: 1.0000
#
# Epoch 00193: loss did not improve from 0.00006
# Epoch 194/200
# 82/82 - 1s - loss: 1.9521e-04 - accuracy: 1.0000
#
# Epoch 00194: loss did not improve from 0.00006
# Epoch 195/200
# 82/82 - 1s - loss: 1.1719e-04 - accuracy: 1.0000
#
# Epoch 00195: loss did not improve from 0.00006
# Epoch 196/200
# 82/82 - 1s - loss: 6.5281e-05 - accuracy: 1.0000
#
# Epoch 00196: loss did not improve from 0.00006
# Epoch 197/200
# 82/82 - 1s - loss: 0.1790 - accuracy: 0.9837
#
# Epoch 00197: loss did not improve from 0.00006
# Epoch 198/200
# 82/82 - 1s - loss: 0.2244 - accuracy: 0.9551
#
# Epoch 00198: loss did not improve from 0.00006
# Epoch 199/200
# 82/82 - 1s - loss: 0.0697 - accuracy: 0.9755
#
# Epoch 00199: loss did not improve from 0.00006
# Epoch 200/200
# 82/82 - 1s - loss: 0.0393 - accuracy: 0.9837
#
# Epoch 00200: loss did not improve from 0.00006
# dict_keys(['loss', 'accuracy'])

# %%
# summarize history for Accuracy
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['accuracy'])
#plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig("model_accuracy.png")

# summarize history for Loss
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['loss'])
#plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig("model_loss.png")

# training metrics
scores = model.evaluate(seq_array, label_array, verbose=1, batch_size=200)
print('Accurracy: {}'.format(scores[1]))

# make predictions and compute confusion matrix
y_pred = model.predict_classes(seq_array,verbose=1, batch_size=200)
y_true = label_array

test_set = pd.DataFrame(y_pred)
test_set.to_csv('binary_submit_train.csv', index = None)

print('Confusion matrix\n- x-axis is true labels.\n- y-axis is predicted labels')
cm = confusion_matrix(y_true, y_pred)
print(cm)

# compute precision and recall
print("Precision:",precision_score(y_true, y_pred, average=None)) 
recall = recall_score(y_true, y_pred, average=None)
print(  'recall = ', recall)
# Out:
# 2/2 [==============================] - 1s 13ms/step - loss: 0.0151 - accuracy: 0.9959
# Accurracy: 0.9959183931350708
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# 2/2 [==============================] - 1s 12ms/step
# Confusion matrix
# - x-axis is true labels.
# - y-axis is predicted labels
# [[209   0]
#  [  1  35]]
# Precision: [0.9952381 1.       ]
# recall =  [1.         0.97222222]

# %%
# pick the feature columns 
sequence_cols=test_df.columns[1:7]

# generator for the sequences
#seq_gen=(list(gen_sequence(train_df[train_df.index==id], sequence_length, sequence_cols))  for id in train_df.index)
seq_gen = list(list(gen_sequence(test_df, sequence_length, sequence_cols)))
           

# generate sequences and convert to numpy array
seq_array = np.concatenate(list(seq_gen)).astype(np.float32)
    
seq_array_test_last=np.reshape(seq_array, (135,10,6))
print(seq_array_test_last.shape)
# Out:
# (135, 10, 6)

# %%
# generate labels
label_gen = [gen_labels(test_df, sequence_length, ['label1'])]
label_array_test_last = np.concatenate(label_gen).astype(np.float32)
print(label_array_test_last.shape)
# Out:
# (135, 1)

# %%
import os
os.chdir("/content")
estimator = load_model("/content")
# test metrics
scores_test = estimator.evaluate(seq_array_test_last, label_array_test_last, verbose=2)
print('Accurracy: {}'.format(scores_test[1]))

# make predictions and compute confusion matrix
y_pred_test = estimator.predict_classes(seq_array_test_last)
y_true_test = label_array_test_last

test_set = pd.DataFrame(y_pred_test)
test_set.to_csv('binary_submit_test.csv', index = None)

print('Confusion matrix\n- x-axis is true labels.\n- y-axis is predicted labels')
cm = confusion_matrix(y_true_test, y_pred_test)
print(cm)

# compute precision and recall
precision_test = precision_score(y_true_test, y_pred_test)
recall_test = recall_score(y_true_test, y_pred_test)
f1_test = 2 * (precision_test * recall_test) / (precision_test + recall_test)
print( 'Precision: ', precision_test, '\n', 'Recall: ', recall_test,'\n', 'F1-score:', f1_test )

# Plot in blue color the predicted data and in green color the
# actual data to verify visually the accuracy of the model.
fig_verify = plt.figure(figsize=(10, 5))
plt.plot(y_pred_test, color="blue")
plt.plot(y_true_test, color="green")
plt.title('prediction')
plt.ylabel('value')
plt.xlabel('row')
plt.legend(['predicted', 'actual data'], loc='upper left')
plt.show()
fig_verify.savefig("model_verify.png")
# Out:
# 5/5 - 1s - loss: 0.5738 - accuracy: 0.9111
# Accurracy: 0.9111111164093018
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Confusion matrix
# - x-axis is true labels.
# - y-axis is predicted labels
# [[123  12]
#  [  0   0]]
# Precision:  0.0
#  Recall:  0.0
#  F1-score: nan
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:23: RuntimeWarning: invalid value encountered in double_scalars
